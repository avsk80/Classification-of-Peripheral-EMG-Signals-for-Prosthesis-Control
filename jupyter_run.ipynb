# %%
# %run test_gpu.py
# Out:
# Num GPUs: 1
# Tensor Flow Version: 2.4.1
# Keras Version: 2.4.0
#
# Python 3.9.17 (main, Jul  5 2023, 20:41:20)
# [GCC 11.2.0]
# Pandas 1.5.3
# Scikit-Learn 1.2.2
# GPU is available

# %%
# %run main_copy.py
# Out:
# Running main...
# data.input_shape = (30, 144, 1)
# data num_classes = 22
# ...

# %%
# %run test.py
# Out:
# Num GPUs: 1
